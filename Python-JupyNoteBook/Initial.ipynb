# %%
abs(-5)
# Out:
# 5

# %%
start = input()

# %%
type(17.5)
# Out:
# float

# %%
type(17)
# Out:
# int

# %%
type("Hello, World!")
# Out:
# str

# %%
round(3.14159, 2)
# Out:
# 3.14

# %%
round(17.5)
# Out:
# 18
