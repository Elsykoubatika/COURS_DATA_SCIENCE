# %%
abs(-5)

# %%
start = input()

# %%
type(17.5)

# %%
def generator():
    print('One!')
    yield
    print('Two!')
    yield
    print('Three!')
    yield
    print('Four!')
    yield
    
g = generator()
g

# %%
next(g)

# %%
next(g)

# %%
def generator():
    n = 1
    print('One!')
    yield n
    
    n += 1
    print('Two!')
    yield n
    
    n+=1
    print('Three!')
    yield n
    
    n +=1
    print('Four!')
    yield n
    
g = generator()
g

# %%
next(g)

# %%
next(g)

# %%
next(g)

# %%
next(g)

# %%
next(g)

# %%
def generator_even_number(limit):
    for i in range(0, limit, 2):
        yield i

# %%
t = generator_even_number(20)
t

# %%
next(t)

# %%
next(t)

# %%
next(t)

# %%
l = list(t)
l

# %%
def generator_square(limit):
    for i in range(0, limit):
        yield i**2
    
s = generator_square(20)
s

# %%
next(s)

# %%
l = list(s)
l

# %%
def generator_powers_of_two():
     num = 0
     while True:
         num = num + 1
         yield 2 ** num
two = generator_powers_of_two()
two

# %%
next(two)

# %%
next(two)

# %%
count = 0

for p in two:
    print(p)
    count = count + 1
    if count > 10:
        break

# %%
#Closures
def get_nested_hello():
    def hello():
        print("Hello Cathy")
    return hello

l = get_nested_hello()
l

# %%
l()

# %%
def greet_hello(name):
    def hello():
        print("Hello", name)
    hello()
    return hello

# %%
greet = greet_hello("Salut")

# %%
#Decorateur 

import random
def print_message():
    print("Elsy sois courageur et continue d'appredre fait le pour la future generation")

def decod():
    anotation = ['-','+','=', ':']
    anotate = random.choice(anotation)
    print(anotate * 80)
    print_message()
    print(anotate*80)
    
decod()

# %%
#Liste

name = []
name

# %%
name = ['elsy', 29, True, 'Honda accord']
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[-1])

# %%
len(name)

# %%
name[3] = 'Fernandez'
print('New:', name[3])
name

# %%
car_list = ['Toyota', 'Nissan', 'Ford', 'Suziki']
# la fonction append ajoute les elements dnas la list
car_list.append('Jetour')

car_list
# Out:
# ['Toyota', 'Nissan', 'Ford', 'Suziki', 'Jetour']

# %%
#insert permet d'inserer un element dans la lite a une position precise

car_list.insert(4, 'Nouveau')
car_list
# Out:
# ['Toyota', 'Nissan', 'Ford', 'Suziki', 'Nouveau', 'Jetour']

# %%
len(car_list)
# Out:
# 7

# %%
# extend ajoute une liste dans une liste (ajouter plus 1 element dans la liste)

car_list.extend(['Roro','Salon'])
car_list
# Out:
# ['Toyota', 'Nissan', 'Ford', 'Suziki', 'Nouveau', 'Jetour', 'Roro', 'Salon']

# %%
#Combiner deux liste avec "+" 

elsy = ['Joel']
completed = elsy + car_list
completed
# Out:
# ['Joel',
#  'Toyota',
#  'Nissan',
#  'Ford',
#  'Suziki',
#  'Nouveau',
#  'Jetour',
#  'Roro',
#  'Salon']

# %%
#Index permet d'acceder a la position d'un element dans la liste

completed.index('Salon')
# Out:
# 8

# %%
# remove permet de supprimer un element dans la liste

completed.remove("Salon")

# %%
completed
# Out:
# ['Joel', 'Toyota', 'Nissan', 'Ford', 'Suziki', 'Nouveau', 'Jetour', 'Roro']

# %%
# sort or classe les element par ordre croissant 
completed.sort()
completed
# Out:
# ['Ford', 'Jetour', 'Joel', 'Nissan', 'Nouveau', 'Roro', 'Suziki', 'Toyota']

# %%
#t reverse change la l'ordre

completed.reverse()
completed
# Out:
# ['Toyota', 'Suziki', 'Roro', 'Nouveau', 'Nissan', 'Joel', 'Jetour', 'Ford']

# %%
# pop fonction remove the last element in the list

completed.pop()
completed
# Out:
# 'Ford'

# %%
completed
# Out:
# ['Toyota', 'Suziki', 'Roro', 'Nouveau', 'Nissan', 'Joel', 'Jetour']

# %%
# count compte le nombre de foid qu'un element apparais dans la list

completed.count('Roro')
# Out:
# 1

# %%
set(completed)
# Out:
# {'Jetour', 'Joel', 'Nissan', 'Nouveau', 'Roro', 'Suziki', 'Toyota'}

# %%
#clear nettoi toute la liste
completed.clear()
completed
# Out:
# []

# %%
import copy

new_completed = copy.deepcopy(completed)

new_completed
# Out:
# ['Toyota', 'Suziki', 'Roro', 'Nouveau', 'Nissan', 'Joel', 'Jetour']

# %%
# del supprimer completement la liste de la memoire

del completed

# %%
# shallow copy using copy.copy()

list_car = new_completed 
list_car
# Out:
# ['Toyota', 'Suziki', 'Roro', 'Nouveau', 'Nissan', 'Joel', 'Jetour']

# %%
list_num = [20, 10, 70, 50, 60 , 100]

max(list_num)
# Out:
# 100

# %%
list_num.append(25)
list_num
# Out:
# [20, 10, 70, 50, 60, 100, 25, 25]

# %%
min(list_num)
# Out:
# 10

# %%
len(list_num)
# Out:
# 8

# %%
list_num.sort()
list_num
# Out:
# [10, 20, 25, 25, 50, 60, 70, 100]

# %%
sorted_list = sorted(list_num)
sorted_list
# Out:
# [10, 20, 25, 25, 50, 60, 70, 100]

# %%
#double liste 
list_num *= 2
list_num
# Out:
# [10,
#  20,
#  25,
#  25,
#  50,
#  60,
#  70,
#  100,
#  10,
#  20,
#  25,
#  25,
#  50,
#  60,
#  70,
#  100,
#  10,
#  20,
#  25,
#  25,
#  50,
#  60,
#  70,
#  100,
#  10,
#  20,
#  25,
#  25,
#  50,
#  60,
#  70,
#  100]

# %%
all([0])
# Out:
# False

# %%
all([1])
# Out:
# True

# %%
all([0,1])
# Out:
# False

# %%
all([1,0])
# Out:
# False

# %%
all(list_num)
# Out:
# True

# %%
any([0])
# Out:
# False

# %%
any([1])
# Out:
# True

# %%
any([1,0])
# Out:
# True

# %%
any(list_num)
# Out:
# True

# %%
#Decoupage permet de recuperer un intervale des element dans la liste
list_num = [20, 10, 70, 50, 60 , 100]

list_num[0:2]
# Out:
# [20, 10]

# %%
list_num[3:]
# Out:
# [50, 60, 100]

# %%
list_num[:3]
# Out:
# [20, 10, 70]

# %%
list_num[-4:-1]
# Out:
# [70, 50, 60]

# %%
#0 est le premiere index, 5 le nombre d'element dans la liste que je veux selectioner 2, le pas (ecart)
list_num[0:5:]
# Out:
# [20, 10, 70, 50, 60]

# %%
list_num[::2]
# Out:
# [20, 70, 60]

# %%
list_num[0:5:2]
# Out:
# [20, 70, 60]

# %%
list_num[6:2] = ['Ford Focus', 'Dodge Charger']
list_num
# Out:
# [20,
#  10,
#  70,
#  50,
#  60,
#  100,
#  'Ford Focus',
#  'Dodge Charger',
#  'Ford Focus',
#  'Dodge Charger']

# %%
'Ford Focus' in list_num
# Out:
# True

# %%
list_num.pop(2)
list_num
# Out:
# [20,
#  10,
#  50,
#  60,
#  100,
#  'Ford Focus',
#  'Dodge Charger',
#  'Ford Focus',
#  'Dodge Charger']

# %%
type(17)

# %%
type("Hello, World!")

# %%
round(3.14159, 2)

# %%
round(17.5)

# %%
x = 'world'
a, b, c, d, e = x
print(b)
# Out:
# o

# %%
a, b, c, d, e
# Out:
# ('w', 'o', 'r', 'd', 'o')

# %%
a, b, _, _, _ = x
print(b)
# Out:
# o

# %%
input('How are you?:')
# Out:
# 'Ok'

# %%
place = input()

# %%
place
# Out:
# 'New York City'

# %%
len(place)
# Out:
# 13

# %%
place[0:8:2]
# Out:
# 'NwYr'

# %%
#Invoking fonction string

print(place.startswith('N'))
print(place.endswith('y'))
# Out:
# True
# True

# %%
place.count('C')
# Out:
# 1

# %%
place.lower()
# Out:
# 'new york city'

# %%
place.upper()
# Out:
# 'NEW YORK CITY'

# %%
place.find('C')
# Out:
# 9

# %%
place.find('CITY')
# Out:
# -1

# %%
place.split('k')
# Out:
# ['New Yor', ' City']

# %%
place.split(' ')
# Out:
# ['New', 'York', 'City']

# %%
chart = ','
chart.join(place)
# Out:
# 'N,e,w, ,Y,o,r,k, ,C,i,t,y'

# %%
"/".join(place)
# Out:
# 'N/e/w/ /Y/o/r/k/ /C/i/t/y'

# %%
some_list = ['a', 'b', 'c', 'd', 'e', 'f']
