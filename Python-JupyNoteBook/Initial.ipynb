# %%
abs(-5)
# Out:
# 5

# %%
start = input()

# %%
type(17.5)
# Out:
# float

# %%
def generator():
    print('One!')
    yield
    print('Two!')
    yield
    print('Three!')
    yield
    print('Four!')
    yield
    
g = generator()
g
# Out:
# <generator object generator at 0x00000160FF1BE5C0>

# %%
next(g)
# Out:
# One!

# %%
next(g)
# Out:
# Two!

# %%
def generator():
    n = 1
    print('One!')
    yield n
    
    n += 1
    print('Two!')
    yield n
    
    n+=1
    print('Three!')
    yield n
    
    n +=1
    print('Four!')
    yield n
    
g = generator()
g
# Out:
# <generator object generator at 0x00000160FF31B6B0>

# %%
next(g)
# Out:
# One!
# 1

# %%
next(g)
# Out:
# Two!
# 2

# %%
next(g)
# Out:
# Three!
# 3

# %%
next(g)
# Out:
# Four!
# 4

# %%
next(g)
# Out:
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 next(g)
#
# StopIteration:

# %%
type(17)
# Out:
# int

# %%
type("Hello, World!")
# Out:
# str

# %%
round(3.14159, 2)
# Out:
# 3.14

# %%
round(17.5)
# Out:
# 18
